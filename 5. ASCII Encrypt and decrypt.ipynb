# %%
# Encryption program
# Step 1: Open file to write encrypted content
file = open('encryption', 'w')
# Step 2: Read file with content line by line
# Step 3: For each line
for line in open('stuff.txt', 'r'):
    print ("line converting - ", line)
    # Step 4: For each character in line
    for c in line:
        # Step 5: convert char to encrypted form 
        # Step 6: call them original and enrypt; ascii is a form of encrypt
        encrypt = ord(c)
        original = c
        print ("got original - ", c)
        print ("converted - ", ord(c))
        file.write(str(encrypt)+ "\n")
# Step 7: Close input and output files
file.close()
# Out:
# line converting -  Someday
#
# got original -  S
# converted -  83
# got original -  o
# converted -  111
# got original -  m
# converted -  109
# got original -  e
# converted -  101
# got original -  d
# converted -  100
# got original -  a
# converted -  97
# got original -  y
# converted -  121
# got original -
#
# converted -  10
# line converting -  Wildside
# got original -  W
# converted -  87
# got original -  i
# converted -  105
# got original -  l
# converted -  108
# got original -  d
# converted -  100
# got original -  s
# converted -  115
# got original -  i
# converted -  105
# got original -  d
# converted -  100
# got original -  e
# converted -  101

# %%
# Decryption program
# Step 1: Open file to write decrypted content 
file = open('decryption', 'w')
# Step 2: Read file with encrypted content line by line
# Step 3: For each line
for line in open('encryption', 'r'):
    # Step 4: For each decrypted character in line // remember: line has original and encrypted
    # do something with line
    #print ("line converting - ", line)
    #for i in line:
    asc = int(line)
    print ("got original - ", line)
    # Step 5: convert char to decrypted form // call them enrypt and original; ascii is a form of encrypt
    # Step 6: write decrypt (original) char and encrypt in a line
    print ("converted - ", chr(asc))
    encrypt = chr(asc)
    original = asc
    file.write(str(encrypt))
# Step 7: Close input and output files
file.close()
# Out:
# got original -  83
#
# converted -  S
# got original -  111
#
# converted -  o
# got original -  109
#
# converted -  m
# got original -  101
#
# converted -  e
# got original -  100
#
# converted -  d
# got original -  97
#
# converted -  a
# got original -  121
#
# converted -  y
# got original -  10
#
# converted -
#
# got original -  87
#
# converted -  W
# got original -  105
#
# converted -  i
# got original -  108
#
# converted -  l
# got original -  100
#
# converted -  d
# got original -  115
#
# converted -  s
# got original -  105
#
# converted -  i
# got original -  100
#
# converted -  d
# got original -  101
#
# converted -  e
